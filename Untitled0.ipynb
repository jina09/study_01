# %% [markdown]
# ## 구글 코랩을 깃허브에 연결하는 방법

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 작업중인 파일의 경로를 지정(다른 곳에서 실행되고 있을 수 있기에)

# %%
test_path = "/content/drive/MyDrive/Github/study_01/"
# %cd "{test_path}" 
# %pwd
# Out:
# /content/drive/MyDrive/Github/study_01
# '/content/drive/MyDrive/Github/study_01'

# %%
with open(test_path + "test_file.txt", "r") as f :
  cont = f.read()
print(cont)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-ad478bedaf0d> in <module>
# ----> 1 with open(test_path + "test_file.txt", "r") as f :
#       2   cont = f.read()
#       3 print(cont)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Github/study_01/test_file.txt'

# %% [markdown]
# ## 쉘 창에서 실행할 수 있도록 해줌 (!git)

# %%
# !git config user.email "jina99932@gmail.com"
# !git config user.name "jina09"

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ## git에 P

# %%
# !git add Untitled0.ipynb
# !git commit -m "Untitled0 initial commit"
# !git push origin main
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@6e64b96b9ca1.(none)')
# Everything up-to-date
